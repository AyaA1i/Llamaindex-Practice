# %%
import os

GOOGLE_API_KEY = "AIzaSyC_gszn7uUoIBhU_nFk4f77XCZC82wfTvc"  
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
from llama_index.llms.gemini import Gemini

mymodel = Gemini(
    model="models/gemini-1.5-flash",
    api_key=GOOGLE_API_KEY
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 from llama_index.llms.gemini import Gemini
# ----> 3 mymodel = Gemini(
#       4     model="models/gemini-1.5-flash",
#       5     api_key=GOOGLE_API_KEY
#       6 )
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\llms\gemini\base.py:161, in Gemini.__init__(self, api_key, model, temperature, max_tokens, generation_config, safety_settings, callback_manager, api_base, transport, model_name, default_headers, **generate_kwargs)
#     158 else:
#     159     max_tokens = min(max_tokens, model_meta.output_token_limit)
# --> 161 super().__init__(
#     162     model=model,
#     163     temperature=temperature,
#     164     max_tokens=max_tokens,
#     165     generate_kwargs=generate_kwargs,
#     166     callback_manager=callback_manager,
#     167 )
#     169 self._model_meta = model_meta
#     170 self._model = genai_model
#
#     [... skipping hidden 1 frame]
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\base\llms\base.py:39, in BaseLLM.check_callback_manager(self)
#      36 @model_validator(mode="after")
#      37 def check_callback_manager(self) -> "BaseLLM":
#      38     if self.callback_manager is None:
# ---> 39         self.callback_manager = CallbackManager([])
#      40     return self
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\callbacks\base.py:59, in CallbackManager.__init__(self, handlers)
#      57 def __init__(self, handlers: Optional[List[BaseCallbackHandler]] = None):
#      58     """Initialize the manager with a list of handlers."""
# ---> 59     from llama_index.core import global_handler
#      61     handlers = handlers or []
#      63     # add eval handlers based on global defaults
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\__init__.py:25
#      21 from llama_index.core.embeddings.mock_embed_model import MockEmbedding
#      23 # indices
#      24 # loading
# ---> 25 from llama_index.core.indices import (
#      26     ComposableGraph,
#      27     DocumentSummaryIndex,
#      28     GPTDocumentSummaryIndex,
#      29     GPTKeywordTableIndex,
#      30     GPTListIndex,
#      31     GPTRAKEKeywordTableIndex,
#      32     GPTSimpleKeywordTableIndex,
#      33     GPTTreeIndex,
#      34     GPTVectorStoreIndex,
#      35     KeywordTableIndex,
#      36     KnowledgeGraphIndex,
#      37     ListIndex,
#      38     PropertyGraphIndex,
#      39     RAKEKeywordTableIndex,
#      40     SimpleKeywordTableIndex,
#      41     SummaryIndex,
#      42     TreeIndex,
#      43     VectorStoreIndex,
#      44     load_graph_from_storage,
#      45     load_index_from_storage,
#      46     load_indices_from_storage,
#      47 )
#      49 # structured
#      50 from llama_index.core.indices.common.struct_store.base import (
#      51     SQLDocumentContextBuilder,
#      52 )
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\indices\__init__.py:32
#      26 from llama_index.core.indices.list import GPTListIndex, ListIndex, SummaryIndex
#      27 from llama_index.core.indices.list.base import (
#      28     GPTListIndex,
#      29     ListIndex,
#      30     SummaryIndex,
#      31 )
# ---> 32 from llama_index.core.indices.loading import (
#      33     load_graph_from_storage,
#      34     load_index_from_storage,
#      35     load_indices_from_storage,
#      36 )
#      37 from llama_index.core.indices.multi_modal import MultiModalVectorStoreIndex
#      38 from llama_index.core.indices.struct_store.pandas import (
#      39     GPTPandasIndex,
#      40     PandasIndex,
#      41 )
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\indices\loading.py:6
#       4 from llama_index.core.indices.base import BaseIndex
#       5 from llama_index.core.indices.composability.graph import ComposableGraph
# ----> 6 from llama_index.core.indices.registry import INDEX_STRUCT_TYPE_TO_INDEX_CLASS
#       7 from llama_index.core.storage.storage_context import StorageContext
#       9 logger = logging.getLogger(__name__)
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\indices\registry.py:13
#      11 from llama_index.core.indices.list.base import SummaryIndex
#      12 from llama_index.core.indices.multi_modal import MultiModalVectorStoreIndex
# ---> 13 from llama_index.core.indices.property_graph import PropertyGraphIndex
#      14 from llama_index.core.indices.struct_store.pandas import PandasIndex
#      15 from llama_index.core.indices.struct_store.sql import SQLStructStoreIndex
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\indices\property_graph\__init__.py:1
# ----> 1 from llama_index.core.indices.property_graph.base import PropertyGraphIndex
#       2 from llama_index.core.indices.property_graph.retriever import PGRetriever
#       3 from llama_index.core.indices.property_graph.sub_retrievers.base import BasePGRetriever
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\indices\property_graph\base.py:17
#      15 from llama_index.core.vector_stores.simple import DEFAULT_VECTOR_STORE
#      16 from llama_index.core.indices.base import BaseIndex
# ---> 17 from llama_index.core.indices.property_graph.transformations import (
#      18     SimpleLLMPathExtractor,
#      19     ImplicitPathExtractor,
#      20 )
#      21 from llama_index.core.ingestion.pipeline import (
#      22     run_transformations,
#      23     arun_transformations,
#      24 )
#      25 from llama_index.core.graph_stores.types import (
#      26     LabelledNode,
#      27     Relation,
#      28     PropertyGraphStore,
#      29     TRIPLET_SOURCE_KEY,
#      30 )
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\indices\property_graph\transformations\__init__.py:4
#       1 from llama_index.core.indices.property_graph.transformations.implicit import (
#       2     ImplicitPathExtractor,
#       3 )
# ----> 4 from llama_index.core.indices.property_graph.transformations.schema_llm import (
#       5     SchemaLLMPathExtractor,
#       6 )
#       7 from llama_index.core.indices.property_graph.transformations.simple_llm import (
#       8     SimpleLLMPathExtractor,
#       9 )
#      10 from llama_index.core.indices.property_graph.transformations.dynamic_llm import (
#      11     DynamicLLMPathExtractor,
#      12 )
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\indices\property_graph\transformations\schema_llm.py:95
#      56 DEFAULT_VALIDATION_SCHEMA: List[Triple] = [
#      57     ("PRODUCT", "USED_BY", "PRODUCT"),
#      58     ("PRODUCT", "USED_FOR", "MARKET"),
#    (...)
#      83     ("LOCATION", "PART_OF", "LOCATION"),
#      84 ]
#      86 DEFAULT_SCHEMA_PATH_EXTRACT_PROMPT = PromptTemplate(
#      87     "Give the following text, extract the knowledge graph according to the provided schema. "
#      88     "Try to limit to the output {max_triplets_per_chunk} extracted paths.s\n"
#    (...)
#      91     "-------\n"
#      92 )
# ---> 95 class SchemaLLMPathExtractor(TransformComponent):
#      96     """
#      97     Extract paths from a graph using a schema.
#      98
#    (...)
#     124             The number of workers to use. Defaults to 4.
#     125     """
#     127     llm: LLM
#
# File c:\Users@DELL5480\test3\venv\lib\site-packages\llama_index\core\indices\property_graph\transformations\schema_llm.py:141, in SchemaLLMPathExtractor()
#     134 possible_relation_props: Optional[List[str]]
#     135 strict: bool
#     137 def __init__(
#     138     self,
#     139     llm: LLM,
#     140     extract_prompt: Optional[Union[PromptTemplate, str]] = None,
# --> 141     possible_entities: Optional[TypeAlias] = None,
#     142     possible_entity_props: Optional[Union[List[str], List[Tuple[str, str]]]] = None,
#     143     possible_relations: Optional[TypeAlias] = None,
#     144     possible_relation_props: Optional[
#     145         Union[List[str], List[Tuple[str, str]]]
#     146     ] = None,
#     147     strict: bool = True,
#     148     kg_schema_cls: Any = None,
#     149     kg_validation_schema: Optional[Union[Dict[str, str], List[Triple]]] = None,
#     150     max_triplets_per_chunk: int = 10,
#     151     num_workers: int = 4,
#     152 ) -> None:
#     153     """Init params."""
#     154     if isinstance(extract_prompt, str):
#
# File c:\Users@DELL5480\test3\venv\lib\typing.py:309, in _tp_cache.<locals>.decorator.<locals>.inner(*args, **kwds)
#     307 except TypeError:
#     308     pass  # All real errors (not unhashable args) are raised below.
# --> 309 return func(*args, **kwds)
#
# File c:\Users@DELL5480\test3\venv\lib\typing.py:400, in _SpecialForm.__getitem__(self, parameters)
#     398 @_tp_cache
#     399 def __getitem__(self, parameters):
# --> 400     return self._getitem(self, parameters)
#
# File c:\Users@DELL5480\test3\venv\lib\typing.py:525, in Optional(self, parameters)
#     519 @_SpecialForm
#     520 def Optional(self, parameters):
#     521     """Optional type.
#     522
#     523     Optional[X] is equivalent to Union[X, None].
#     524     """
# --> 525     arg = _type_check(parameters, f"{self} requires a single type.")
#     526     return Union[arg, type(None)]
#
# File c:\Users@DELL5480\test3\venv\lib\typing.py:169, in _type_check(arg, msg, is_argument, module)
#     167     return arg
#     168 if isinstance(arg, _SpecialForm) or arg in (Generic, Protocol):
# --> 169     raise TypeError(f"Plain {arg} is not valid as type argument")
#     170 if isinstance(arg, (type, TypeVar, ForwardRef, types.UnionType, ParamSpec)):
#     171     return arg
#
# TypeError: Plain typing.TypeAlias is not valid as type argument

# %%
from llama_index.legacy import VectorStoreIndex,SimpleDirectoryReader,ServiceContext,PromptTemplate
documents = SimpleDirectoryReader("data").load_data()

# %%
resp = llm.complete("Write a short, but joyous, ode to LlamaIndex")
print(resp)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[34], line 4
#       1 from openai import AsyncOpenAI
#       3 client = AsyncOpenAI()
# ----> 4 completion = await client.chat.completions.create(model="gpt-3.5-turbo", messages=[{"role": "user", "content": "Hello world"}])
#
# File c:\Users\DELL 5480\Downloads\llamaindex\venv\lib\site-packages\openai\resources\chat\completions.py:1661, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1620 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1621 async def create(
#    1622     self,
#    (...)
#    1658     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1659 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    1660     validate_response_format(response_format)
# -> 1661     return await self._post(
#    1662         "/chat/completions",
#    1663         body=await async_maybe_transform(
#    1664             {
#    1665                 "messages": messages,
#    1666                 "model": model,
#    1667                 "audio": audio,
#    1668                 "frequency_penalty": frequency_penalty,
#    1669                 "function_call": function_call,
#    1670                 "functions": functions,
#    1671                 "logit_bias": logit_bias,
#    1672                 "logprobs": logprobs,
#    1673                 "max_completion_tokens": max_completion_tokens,
#    1674                 "max_tokens": max_tokens,
#    1675                 "metadata": metadata,
#    1676                 "modalities": modalities,
#    1677                 "n": n,
#    1678                 "parallel_tool_calls": parallel_tool_calls,
#    1679                 "prediction": prediction,
#    1680                 "presence_penalty": presence_penalty,
#    1681                 "response_format": response_format,
#    1682                 "seed": seed,
#    1683                 "service_tier": service_tier,
#    1684                 "stop": stop,
#    1685                 "store": store,
#    1686                 "stream": stream,
#    1687                 "stream_options": stream_options,
#    1688                 "temperature": temperature,
#    1689                 "tool_choice": tool_choice,
#    1690                 "tools": tools,
#    1691                 "top_logprobs": top_logprobs,
#    1692                 "top_p": top_p,
#    1693                 "user": user,
#    1694             },
#    1695             completion_create_params.CompletionCreateParams,
#    1696         ),
#    1697         options=make_request_options(
#    1698             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1699         ),
#    1700         cast_to=ChatCompletion,
#    1701         stream=stream or False,
#    1702         stream_cls=AsyncStream[ChatCompletionChunk],
#    1703     )
#
# File c:\Users\DELL 5480\Downloads\llamaindex\venv\lib\site-packages\openai\_base_client.py:1843, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1829 async def post(
#    1830     self,
#    1831     path: str,
#    (...)
#    1838     stream_cls: type[_AsyncStreamT] | None = None,
#    1839 ) -> ResponseT | _AsyncStreamT:
#    1840     opts = FinalRequestOptions.construct(
#    1841         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1842     )
# -> 1843     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Users\DELL 5480\Downloads\llamaindex\venv\lib\site-packages\openai\_base_client.py:1537, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1534 else:
#    1535     retries_taken = 0
# -> 1537 return await self._request(
#    1538     cast_to=cast_to,
#    1539     options=options,
#    1540     stream=stream,
#    1541     stream_cls=stream_cls,
#    1542     retries_taken=retries_taken,
#    1543 )
#
# File c:\Users\DELL 5480\Downloads\llamaindex\venv\lib\site-packages\openai\_base_client.py:1623, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1621 if remaining_retries > 0 and self._should_retry(err.response):
#    1622     await err.response.aclose()
# -> 1623     return await self._retry_request(
#    1624         input_options,
#    1625         cast_to,
#    1626         retries_taken=retries_taken,
#    1627         response_headers=err.response.headers,
#    1628         stream=stream,
#    1629         stream_cls=stream_cls,
#    1630     )
#    1632 # If the response is streamed then we need to explicitly read the response
#    1633 # to completion before attempting to access the response text.
#    1634 if not err.response.is_closed:
#
# File c:\Users\DELL 5480\Downloads\llamaindex\venv\lib\site-packages\openai\_base_client.py:1670, in AsyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1666 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1668 await anyio.sleep(timeout)
# -> 1670 return await self._request(
#    1671     options=options,
#    1672     cast_to=cast_to,
#    1673     retries_taken=retries_taken + 1,
#    1674     stream=stream,
#    1675     stream_cls=stream_cls,
#    1676 )
#
# File c:\Users\DELL 5480\Downloads\llamaindex\venv\lib\site-packages\openai\_base_client.py:1623, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1621 if remaining_retries > 0 and self._should_retry(err.response):
#    1622     await err.response.aclose()
# -> 1623     return await self._retry_request(
#    1624         input_options,
#    1625         cast_to,
#    1626         retries_taken=retries_taken,
#    1627         response_headers=err.response.headers,
#    1628         stream=stream,
#    1629         stream_cls=stream_cls,
#    1630     )
#    1632 # If the response is streamed then we need to explicitly read the response
#    1633 # to completion before attempting to access the response text.
#    1634 if not err.response.is_closed:
#
# File c:\Users\DELL 5480\Downloads\llamaindex\venv\lib\site-packages\openai\_base_client.py:1670, in AsyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1666 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1668 await anyio.sleep(timeout)
# -> 1670 return await self._request(
#    1671     options=options,
#    1672     cast_to=cast_to,
#    1673     retries_taken=retries_taken + 1,
#    1674     stream=stream,
#    1675     stream_cls=stream_cls,
#    1676 )
#
# File c:\Users\DELL 5480\Downloads\llamaindex\venv\lib\site-packages\openai\_base_client.py:1638, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1635         await err.response.aread()
#    1637     log.debug("Re-raising status error")
# -> 1638     raise self._make_status_error_from_response(err.response) from None
#    1640 return await self._process_response(
#    1641     cast_to=cast_to,
#    1642     options=options,
#    (...)
#    1646     retries_taken=retries_taken,
#    1647 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
