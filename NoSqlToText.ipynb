# %%
pip install llama-index-llms-gemini llama-index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.1/679.1 kB 14.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 34.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 57.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.8/195.8 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
# ...

# %%
# !pip install llama-index-readers-mongodb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 15.2 MB/s eta 0:00:00
# ...

# %%
# !pip install llama-index pymongo

# %%
import os

from sqlalchemy import create_engine

from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core import SQLDatabase
from llama_index.llms.openai import OpenAI
from llama_index.llms.gemini import Gemini
from llama_index.core import SummaryIndex
from llama_index.readers.mongodb import SimpleMongoReader
from IPython.display import Markdown, display

# %%
GOOGLE_API_KEY = "AIzaSyAUc_etSz0TUkkyKMOUm4yw3CnxCmQUrnc"  # add your GOOGLE API key here
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi


client = MongoClient("mongodb+srv://AyaA1i:Ayaali22@cluster0.kw1bb.mongodb.net/testllamaindex?retryWrites=true&w=majority&appName=Cluster0")

# db = client['db1']
# collection = db['youtube']

# document = {"name":"sktech", "city":"pune"}
# insert_doc = collection. insert_one(document)

# print(f"instered Document ID : {insert_doc.inserted_id}")
# client.close()
db_name = "sample_mflix"
collection_name = "movies"
# query_dict is passed into db.collection.find()
query_dict = {}
field_names = ["title"]
reader = SimpleMongoReader(
    host="cluster0.kw1bb.mongodb.net",
    port=27017,
    uri="mongodb+srv://AyaA1i:Ayaali22@cluster0.kw1bb.mongodb.net/testllamaindex?retryWrites=true&w=majority&appName=Cluster0", )
documents = reader.load_data(
    db_name, collection_name, field_names,query_dict=query_dict
)

# %%
llm = Gemini(
    model="models/gemini-1.5-flash",
    api_key=GOOGLE_API_KEY,
)

# %%
index = SummaryIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine(llm=llm)
response = query_engine.query("how many movies")

# %%
print(response)
# Out:
# The provided text lists 2177 movies.
